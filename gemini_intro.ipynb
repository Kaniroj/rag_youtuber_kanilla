# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="models/gemini-2.5-flash",
    contents="Generate 5 funny jokes about data engineering."
)

print(response.text)
# Out:
# Here are 5 funny jokes about data engineering:
#
# 1.  Why did the data engineer get banned from the library?
#     Because they kept trying to normalize the Dewey Decimal System and *change the schema* without permission!
#
# 2.  What's a data engineer's favorite magic trick?
#     Making 100 broken source systems look like one clean, normalized dataset.
#
# 3.  Why don't data engineers ever play hide-and-seek?
#     Because they're always worried about finding *NULL* values.
#
# 4.  A data scientist asks, "Can we build a model to predict X?" A data analyst asks, "Can we get a report on Y?"
#     A data engineer just sighs and says, "Can we *get* X and Y into the data warehouse first, please?"
#
# 5.  What's a data engineer's definition of "clean data"?
#     "Data that only *occasionally* makes my production pipelines explode at 3 AM."

# %% [markdown]
# Gemini intro
